# %%
import  os 
import  pandas  as  pd 
import  numpy  as  np 
import  matplotlib  as  mpl 
from  matplotlib  
import  pyplot  as  plt
import  datetime
import  json
import seaborn as sns

# %%
#Setting Working Directory 
os.getcwd()
os.chdir('/Users/Bhaktii/Downloads')

# %%
asia = pd.read_csv('ASIA_trending.csv')

# %%
eu = pd.read_csv('EU_trending.csv')

# %%
na = pd.read_csv('NA_trending.csv')

# %%
vd = pd.read_csv('videos.csv')

# %%
asia
# Out:
#           video_id trending_date      views likes/dislikes  comment_count  \
# 0      kzwfHumJyYc      17.14.11  1096327.0      33966/798          882.0
# 1      zUZ1z7FwLc8      17.14.11   590101.0        735/904            0.0
# 2      10L1hZ9qa58      17.14.11   473988.0       2011/243          149.0
# 3      N1vE8iiEg64      17.14.11  1242680.0     70353/1624         2684.0
# 4      kJzGH0PVQHQ      17.14.11   464015.0        492/293           66.0
# ...            ...           ...        ...            ...            ...
# 47277  dVXOIs28etI      18.14.06   303803.0       1162/261            0.0
# 47278  YdGVl1-WEgg      18.14.06    17237.0         369/29           93.0
# 47279  nIv_uRQdH44      18.14.06    82238.0        105/280          226.0
# 47280  DscOCnDp-rg      18.14.06   160617.0       4495/334          897.0
# 47281  YVdnWeL5qsY      18.14.06  1101410.0      4061/1733         7796.0
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg                  0
# 1      https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg                  1
# 2      https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg                  0
# 3      https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg                  0
# 4      https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg                  0
# ...                                               ...                ...
# 47277  https://i.ytimg.com/vi/dVXOIs28etI/default.jpg                  1
# 47278  https://i.ytimg.com/vi/YdGVl1-WEgg/default.jpg                  0
# 47279  https://i.ytimg.com/vi/nIv_uRQdH44/default.jpg                  0
# 47280  https://i.ytimg.com/vi/DscOCnDp-rg/default.jpg                  0
# 47281  https://i.ytimg.com/vi/YVdnWeL5qsY/default.jpg                  0
#
#        ratings_disabled  video_error_or_removed    country
# 0                 False                   False  India
# 1                 False                   False  India
# 2                 False                   False  India
# 3                 False                   False  India
# 4                 False                   False  India
# ...                 ...                     ...        ...
# 47277             False                   False  Japan
# 47278             False                   False  Japan
# 47279             False                   False  Japan
# 47280             False                   False  Japan
# 47281             False                   False  Japan
#
# [47282 rows x 10 columns]

# %%
eu
# Out:
#            video_id trending_date       views likes/dislikes  comment_count  \
# 0       LgVi6y5QIjM      17.14.11    252786.0      35885/230         1539.0
# 1       Bayt7uQith4      17.14.11    797196.0      53576/302         1278.0
# 2       1ZAPwfrtAFY      17.14.11   2418783.0     97190/6146        12703.0
# 3       AHtypnRk7JE      17.14.11    380247.0      31821/458         1955.0
# 4       ZJ9We4bjcg0      17.14.11         NaN    100684/2467            NaN
# ...             ...           ...         ...            ...            ...
# 119581  l884wKofd54      18.14.06         NaN   268088/12783         9933.0
# 119582  IP8k2xkhOdI      18.14.06   1492219.0    61998/13781        24330.0
# 119583  Il-an3K9pjg      18.14.06  29641412.0    394830/8892        19988.0
# 119584  -DRsfNObKIQ      18.14.06  14317515.0   151870/45875        26766.0
# 119585  4YFo4bdMO8Q      18.14.06    607552.0      18271/274         1423.0
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/LgVi6y5QIjM/default.jpg              False
# 1       https://i.ytimg.com/vi/Bayt7uQith4/default.jpg              False
# 2       https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 3       https://i.ytimg.com/vi/AHtypnRk7JE/default.jpg              False
# 4       https://i.ytimg.com/vi/ZJ9We4bjcg0/default.jpg              False
# ...                                                ...                ...
# 119581  https://i.ytimg.com/vi/l884wKofd54/default.jpg              False
# 119582  https://i.ytimg.com/vi/IP8k2xkhOdI/default.jpg              False
# 119583  https://i.ytimg.com/vi/Il-an3K9pjg/default.jpg              False
# 119584  https://i.ytimg.com/vi/-DRsfNObKIQ/default.jpg              False
# 119585  https://i.ytimg.com/vi/4YFo4bdMO8Q/default.jpg              False
#
#         ratings_disabled  video_error_or_removed      country
# 0                  False                   False  Germany
# 1                  False                   False  Germany
# 2                  False                   False  Germany
# 3                  False                   False  Germany
# 4                  False                   False  Germany
# ...                  ...                     ...          ...
# 119581             False                   False       UK
# 119582             False                   False       UK
# 119583             False                   False       UK
# 119584             False                   False       UK
# 119585             False                   False       UK
#
# [119586 rows x 10 columns]

# %%
na
# Out:
#           video_id trending_date       views likes/dislikes  comment_count  \
# 0      n1WpP7iowLc      17.14.11  17158579.0   787425/43420       125882.0
# 1      0dBIkQ4Mz1M      17.14.11   1014651.0    127794/1688        13030.0
# 2      5qpjK5DgCt4      17.14.11   3191434.0    146035/5339         8181.0
# 3      d380meD0W0M      17.14.11   2095828.0    132239/1989        17518.0
# 4      2Vv-BfVoq4g      17.14.11  33523622.0  1634130/21082        85067.0
# ...            ...           ...         ...            ...            ...
# 81379  BZt0qjTWNhw      18.14.06   1685609.0     38160/1385         2657.0
# 81380  1h7KV2sjUWY      18.14.06   1064798.0      60008/382         3936.0
# 81381  D6Oy4LfoqsU      18.14.06   1066451.0     48068/1032         3992.0
# 81382  oV0zkMe1K8s      18.14.06   5660813.0    192957/2846        13088.0
# 81383  ooyjaVdt-jA      18.14.06  10306119.0  357079/212976       144795.0
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 1      https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# 4      https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg              False
# ...                                               ...                ...
# 81379  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 81380  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 81381  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 81382  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 81383  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed     country
# 0                 False                   False  Canada
# 1                 False                   False  Canada
# 2                 False                   False  Canada
# 3                 False                   False  Canada
# 4                 False                   False  Canada
# ...                 ...                     ...         ...
# 81379             False                   False      US
# 81380             False                   False      US
# 81381             False                   False      US
# 81382             False                   False      US
# 81383             False                   False      US
#
# [81384 rows x 10 columns]

# %%
vd
# Out:
#            video_id                                              title  \
# 0       n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1       0dBIkQ4Mz1M                      PLUSH - Bad Unboxing Fan Mail
# 2       5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3       d380meD0W0M                           I Dare You: GOING BALD!?
# 4       2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# ...             ...                                                ...
# 107031  DjLr06pne6Q  Jorja Smith Gets Ready for Bed | Beauty Secret...
# 107032  8O-ZUXGcuWU                          Nintendo @ E3 2018: Day 2
# 107033  qPEIPu0V8GQ         Fortnite Celebrity Pro-Am | #FortniteProAm
# 107034  dS5Thrl-4Kc                      CRAYOLA MAKEUP | HIT OR MISS?
# 107035  yz7Xq3T0YPs  Katherine Langford on 13 Reasons Why, Australi...
#
#             channel_title  category_id         publish_time
# 0              EminemVEVO           10  2017-11-10 17:00:03
# 1               iDubbbzTV           23  2017-11-13 17:00:00
# 2            Rudy Mancuso           23  2017-11-12 19:05:24
# 3                nigahiga           24  2017-11-12 18:01:41
# 4              Ed Sheeran           10  2017-11-09 11:04:14
# ...                   ...          ...                  ...
# 107031              Vogue           26  2018-06-12 13:48:29
# 107032           Nintendo           20  2018-06-14 01:31:53
# 107033           Fortnite           20  2018-06-13 03:27:30
# 107034          Laura Lee           26  2018-06-12 18:55:26
# 107035  Jimmy Kimmel Live           24  2018-06-13 09:00:06
#
# [107036 rows x 5 columns]

# %%
#EDA
print(vd.shape)
print(vd.head())
vd.tail()
# Out:
# (107036, 5)
#       video_id                                              title  \
# 0  n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M                      PLUSH - Bad Unboxing Fan Mail
# 2  5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3  d380meD0W0M                           I Dare You: GOING BALD!?
# 4  2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title  category_id         publish_time
# 0    EminemVEVO           10  2017-11-10 17:00:03
# 1     iDubbbzTV           23  2017-11-13 17:00:00
# 2  Rudy Mancuso           23  2017-11-12 19:05:24
# 3      nigahiga           24  2017-11-12 18:01:41
# 4    Ed Sheeran           10  2017-11-09 11:04:14
#            video_id                                              title  \
# 107031  DjLr06pne6Q  Jorja Smith Gets Ready for Bed | Beauty Secret...
# 107032  8O-ZUXGcuWU                          Nintendo @ E3 2018: Day 2
# 107033  qPEIPu0V8GQ         Fortnite Celebrity Pro-Am | #FortniteProAm
# 107034  dS5Thrl-4Kc                      CRAYOLA MAKEUP | HIT OR MISS?
# 107035  yz7Xq3T0YPs  Katherine Langford on 13 Reasons Why, Australi...
#
#             channel_title  category_id         publish_time
# 107031              Vogue           26  2018-06-12 13:48:29
# 107032           Nintendo           20  2018-06-14 01:31:53
# 107033           Fortnite           20  2018-06-13 03:27:30
# 107034          Laura Lee           26  2018-06-12 18:55:26
# 107035  Jimmy Kimmel Live           24  2018-06-13 09:00:06

# %%
vd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107036 entries, 0 to 107035
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   video_id       107036 non-null  object
#  1   title          107036 non-null  object
#  2   channel_title  107036 non-null  object
#  3   category_id    107036 non-null  int64
#  4   publish_time   107036 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.1+ MB

# %%
#Splitting publish time column within the videos dataset to time and date columns
vd['publish_time'].str.split( ' ', n = 1, expand = True)
# Out:
#                  0         1
# 0       2017-11-10  17:00:03
# 1       2017-11-13  17:00:00
# 2       2017-11-12  19:05:24
# 3       2017-11-12  18:01:41
# 4       2017-11-09  11:04:14
# ...            ...       ...
# 107031  2018-06-12  13:48:29
# 107032  2018-06-14  01:31:53
# 107033  2018-06-13  03:27:30
# 107034  2018-06-12  18:55:26
# 107035  2018-06-13  09:00:06
#
# [107036 rows x 2 columns]

# %%
#Frequency table for different categories in the videos dataset
CategoryCount = pd.crosstab(index = vd["category_id"], columns = "count")
CategoryCount
# Out:
# col_0        count
# category_id
# 1             5163
# 2             1786
# 10            6851
# 15            1412
# 17            8582
# 19             503
# 20            3476
# 22           14794
# 23            6837
# 24           34715
# 25           11760
# 26            5587
# 27            2756
# 28            2139
# 29             439
# 30              11
# 43             223
# 44               2

# %%
#Bar Graph for the above frquency table for categories and their respective counts
vd["category_id"].value_counts().plot(kind="bar", title= "Category Counts", xlabel="Categories", ylabel="No. of Videos", color="#8B3A62")

print ("Conclusion: From the table and the chart, it is evident that category ID 24 has the highest number of trending videos. As per our assumption, it is the Entertainment Category.")
# Out:
# Conclusion: From the table and the chart, it is evident that category ID 24 has the highest number of trending videos. As per our assumption, it is the Entertainment Category.

# %%
#Merging the three datasets for different regions, that is, Asia, EU, NA into one consolidated dataset for ease of analysis
youtube = pd.concat(map(pd.read_csv, ['Asia_trending.csv','EU_trending.csv','NA_trending.csv']), ignore_index = True)
youtube
# Out:
#            video_id trending_date       views likes/dislikes  comment_count  \
# 0       kzwfHumJyYc      17.14.11   1096327.0      33966/798          882.0
# 1       zUZ1z7FwLc8      17.14.11    590101.0        735/904            0.0
# 2       10L1hZ9qa58      17.14.11    473988.0       2011/243          149.0
# 3       N1vE8iiEg64      17.14.11   1242680.0     70353/1624         2684.0
# 4       kJzGH0PVQHQ      17.14.11    464015.0        492/293           66.0
# ...             ...           ...         ...            ...            ...
# 248247  BZt0qjTWNhw      18.14.06   1685609.0     38160/1385         2657.0
# 248248  1h7KV2sjUWY      18.14.06   1064798.0      60008/382         3936.0
# 248249  D6Oy4LfoqsU      18.14.06   1066451.0     48068/1032         3992.0
# 248250  oV0zkMe1K8s      18.14.06   5660813.0    192957/2846        13088.0
# 248251  ooyjaVdt-jA      18.14.06  10306119.0  357079/212976       144795.0
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg                  0
# 1       https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg                  1
# 2       https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg                  0
# 3       https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg                  0
# 4       https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg                  0
# ...                                                ...                ...
# 248247  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg                  0
# 248248  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg                  0
# 248249  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg                  0
# 248250  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg                  0
# 248251  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg                  0
#
#         ratings_disabled  video_error_or_removed    country
# 0                  False                   False  India
# 1                  False                   False  India
# 2                  False                   False  India
# 3                  False                   False  India
# 4                  False                   False  India
# ...                  ...                     ...        ...
# 248247             False                   False     US
# 248248             False                   False     US
# 248249             False                   False     US
# 248250             False                   False     US
# 248251             False                   False     US
#
# [248252 rows x 10 columns]

# %%
#EDA
print(youtube.shape)
# Out:
# (248252, 10)

# %%
#EDA
youtube.head()
# Out:
#       video_id trending_date      views likes/dislikes  comment_count  \
# 0  kzwfHumJyYc      17.14.11  1096327.0      33966/798          882.0
# 1  zUZ1z7FwLc8      17.14.11   590101.0        735/904            0.0
# 2  10L1hZ9qa58      17.14.11   473988.0       2011/243          149.0
# 3  N1vE8iiEg64      17.14.11  1242680.0     70353/1624         2684.0
# 4  kJzGH0PVQHQ      17.14.11   464015.0        492/293           66.0
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg                  0
# 1  https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg                  1
# 2  https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg                  0
# 3  https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg                  0
# 4  https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg                  0
#
#    ratings_disabled  video_error_or_removed    country
# 0             False                   False  India
# 1             False                   False  India
# 2             False                   False  India
# 3             False                   False  India
# 4             False                   False  India

# %%
#EDA
youtube.tail()
# Out:
#            video_id trending_date       views likes/dislikes  comment_count  \
# 248247  BZt0qjTWNhw      18.14.06   1685609.0     38160/1385         2657.0
# 248248  1h7KV2sjUWY      18.14.06   1064798.0      60008/382         3936.0
# 248249  D6Oy4LfoqsU      18.14.06   1066451.0     48068/1032         3992.0
# 248250  oV0zkMe1K8s      18.14.06   5660813.0    192957/2846        13088.0
# 248251  ooyjaVdt-jA      18.14.06  10306119.0  357079/212976       144795.0
#
#                                         thumbnail_link  comments_disabled  \
# 248247  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg                  0
# 248248  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg                  0
# 248249  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg                  0
# 248250  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg                  0
# 248251  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg                  0
#
#         ratings_disabled  video_error_or_removed country
# 248247             False                   False  US
# 248248             False                   False  US
# 248249             False                   False  US
# 248250             False                   False  US
# 248251             False                   False  US

# %%
#EDA
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248252 entries, 0 to 248251
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                248252 non-null  object
#  1   trending_date           248252 non-null  object
#  2   views                   238402 non-null  float64
#  3   likes/dislikes          248252 non-null  object
#  4   comment_count           240856 non-null  float64
#  5   thumbnail_link          248252 non-null  object
#  6   comments_disabled       248252 non-null  int64
#  7   ratings_disabled        248252 non-null  bool
#  8   video_error_or_removed  248252 non-null  bool
#  9   country                 248252 non-null  object
# dtypes: bool(2), float64(2), int64(1), object(5)
# memory usage: 15.6+ MB

# %%
#Changing dataset column of likes/dislikes with split value columns for likes and dislikes 
youtube [["likes","dislikes"]] = youtube ["likes/dislikes"].str.split("/", n = 1, expand = True)
youtube ['likes'] = pd.to_numeric(youtube['likes'])
youtube['dislikes'] = pd.to_numeric(youtube['dislikes'])
youtube
# Out:
#            video_id trending_date       views likes/dislikes  comment_count  \
# 0       kzwfHumJyYc      17.14.11   1096327.0      33966/798          882.0
# 1       zUZ1z7FwLc8      17.14.11    590101.0        735/904            0.0
# 2       10L1hZ9qa58      17.14.11    473988.0       2011/243          149.0
# 3       N1vE8iiEg64      17.14.11   1242680.0     70353/1624         2684.0
# 4       kJzGH0PVQHQ      17.14.11    464015.0        492/293           66.0
# ...             ...           ...         ...            ...            ...
# 248247  BZt0qjTWNhw      18.14.06   1685609.0     38160/1385         2657.0
# 248248  1h7KV2sjUWY      18.14.06   1064798.0      60008/382         3936.0
# 248249  D6Oy4LfoqsU      18.14.06   1066451.0     48068/1032         3992.0
# 248250  oV0zkMe1K8s      18.14.06   5660813.0    192957/2846        13088.0
# 248251  ooyjaVdt-jA      18.14.06  10306119.0  357079/212976       144795.0
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg                  0
# 1       https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg                  1
# 2       https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg                  0
# 3       https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg                  0
# 4       https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg                  0
# ...                                                ...                ...
# 248247  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg                  0
# 248248  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg                  0
# 248249  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg                  0
# 248250  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg                  0
# 248251  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg                  0
#
#         ratings_disabled  video_error_or_removed    country   likes  dislikes
# 0                  False                   False  India       33966       798
# 1                  False                   False  India         735       904
# 2                  False                   False  India        2011       243
# 3                  False                   False  India       70353      1624
# 4                  False                   False  India         492       293
# ...                  ...                     ...        ...     ...       ...
# 248247             False                   False     US       38160      1385
# 248248             False                   False     US       60008       382
# 248249             False                   False     US       48068      1032
# 248250             False                   False     US      192957      2846
# 248251             False                   False     US      357079    212976
#
# [248252 rows x 12 columns]

# %%
#Drop unnecessary columns w.r.t to the analysis
youtube = youtube.drop (columns = ['thumbnail_link','likes/dislikes'])

# %%
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248252 entries, 0 to 248251
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                248252 non-null  object
#  1   trending_date           248252 non-null  object
#  2   views                   238402 non-null  float64
#  3   comment_count           240856 non-null  float64
#  4   comments_disabled       248252 non-null  int64
#  5   ratings_disabled        248252 non-null  bool
#  6   video_error_or_removed  248252 non-null  bool
#  7   country                 248252 non-null  object
#  8   likes                   248252 non-null  int64
#  9   dislikes                248252 non-null  int64
# dtypes: bool(2), float64(2), int64(3), object(3)
# memory usage: 15.6+ MB

# %%
#Change Datatypes as required
youtube['trending_date']= youtube['trending_date'].astype('category')
youtube['comments_disabled']= youtube['comments_disabled'].astype('category')
youtube['country']= youtube['country'].astype('category')

# %%
#EDA
youtube.describe()
# Out:
#               views  comment_count         likes      dislikes
# count  2.384020e+05   2.408560e+05  2.482520e+05  2.482520e+05
# mean   1.807737e+06   5.426361e+03  5.001085e+04  2.720341e+03
# std    8.511994e+06   2.917504e+04  1.919208e+05  2.655401e+04
# min    2.230000e+02   0.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.249525e+04   1.530000e+02  1.064000e+03  6.200000e+01
# 50%    2.778715e+05   7.190000e+02  5.713500e+03  2.650000e+02
# 75%    9.695110e+05   2.853000e+03  2.670500e+04  1.034000e+03
# max    4.245389e+08   1.626501e+06  5.613827e+06  1.944971e+06

# %%
#Formatting the given trending date in the dataset
youtube.trending_date = pd.to_datetime(youtube.trending_date, format='%y.%d.%m')
dates = youtube['trending_date'].dt
youtube["Year"] = dates.year
youtube["Month"] = dates.month
youtube["Day"] = dates.day
youtube['Weekday'] = dates.day_name()

# %%
#EDA
youtube.head()
# Out:
#       video_id trending_date      views  comment_count comments_disabled  \
# 0  kzwfHumJyYc    2017-11-14  1096327.0          882.0                 0
# 1  zUZ1z7FwLc8    2017-11-14   590101.0            0.0                 1
# 2  10L1hZ9qa58    2017-11-14   473988.0          149.0                 0
# 3  N1vE8iiEg64    2017-11-14  1242680.0         2684.0                 0
# 4  kJzGH0PVQHQ    2017-11-14   464015.0           66.0                 0
#
#    ratings_disabled  video_error_or_removed    country  likes  dislikes  Year  \
# 0             False                   False  India      33966       798  2017
# 1             False                   False  India        735       904  2017
# 2             False                   False  India       2011       243  2017
# 3             False                   False  India      70353      1624  2017
# 4             False                   False  India        492       293  2017
#
#    Month  Day  Weekday
# 0     11   14  Tuesday
# 1     11   14  Tuesday
# 2     11   14  Tuesday
# 3     11   14  Tuesday
# 4     11   14  Tuesday

# %%
#Table for Countries and Videos with Error or Videos removed 
table1 = pd.crosstab(index=youtube["country"],columns="video_error_or_removed")
print(table1)
print("Conclusion: Germany and Canada noticably have the highest number of videos with an error or videos removed.")
# Out:
# col_0        video_error_or_removed
# country
# Canada                        40808
# France                        40660
# Germany                       40819
# India                         32645
# Japan                         14637
# UK                            38107
# US                            40576
# Conclusion: Germany and Canada noticably have the highest number of videos with an error or videos removed.

# %%
#How many trending videos have their ratings disabled?

youtube["ratings_disabled"].value_counts().plot.pie(y='How many trending videos have their ratings disabled?', figsize=(5, 5), title='How many trending videos have their ratings disabled?', ylabel=' ', colors=['#003f5c', '#ffa600'])
print('Conclusion:Very few trending videos had their ratings disabled from the total cohort in the dataset. Since ratings play a significant role in the matter of whether a video goes viral or not and hence the lower fraction.')
# Out:
# Conclusion:Very few trending videos had their ratings disabled from the total cohort in the dataset. Since ratings play a significant role in the matter of whether a video goes viral or not and hence the lower fraction.

# %%
youtube["ratings_disabled"].value_counts()
# Out:
# False    244474
# True       3778
# Name: ratings_disabled, dtype: int64

# %%
#How many trending videos have their comments disabled?

youtube["comments_disabled"].value_counts().plot.pie(y='How many trending videos have their comments disabled?', figsize=(5, 5), title='How many trending videos have their comments disabled?', ylabel=' ', colors=['#003f5c', '#ffa600'])

print("Conclusion: Very few trending videos have their comments disabled because, as in the case of ratings, comments too are instrumental in impacting the reach if a video.")
# Out:
# Conclusion: Very few trending videos have their comments disabled because, as in the case of ratings, comments too are instrumental in impacting the reach if a video.

# %%
youtube["comments_disabled"].value_counts(normalize=True)
# Out:
# 0    0.976395
# 1    0.023605
# Name: comments_disabled, dtype: float64

# %%
#How many trending videos have an error ir were removed?

youtube["video_error_or_removed"].value_counts().plot.pie(y='How many trending videos have an error or were removed?', figsize=(5, 5), title='How many trending videos have an error or were removed?', ylabel=' ', colors=['#003f5c', '#ffa600'])
print("Conclusion: A negligible fraction of the trending videos had an error or were removed.")
# Out:
# Conclusion: A negligible fraction of the trending videos had an error or were removed.

# %%
youtube["video_error_or_removed"].value_counts()
# Out:
# False    248081
# True        171
# Name: video_error_or_removed, dtype: int64

# %%
#Correlation calculations for the merged dataset of the given three regions
correlation=youtube.corr()
correlation
# Out:
#                            views  comment_count  ratings_disabled  \
# views                   1.000000       0.499697         -0.008628
# comment_count           0.499697       1.000000         -0.021514
# ratings_disabled       -0.008628      -0.021514          1.000000
# video_error_or_removed  0.009946       0.004067         -0.003264
# likes                   0.782278       0.781943         -0.032393
# dislikes                0.412920       0.723933         -0.012735
# Year                    0.046081       0.014896          0.010829
# Month                  -0.020483      -0.000557         -0.012004
# Day                    -0.003961      -0.001488         -0.002311
#
#                         video_error_or_removed     likes  dislikes      Year  \
# views                                 0.009946  0.782278  0.412920  0.046081
# comment_count                         0.004067  0.781943  0.723933  0.014896
# ratings_disabled                     -0.003264 -0.032393 -0.012735  0.010829
# video_error_or_removed                1.000000  0.008684  0.006850  0.012764
# likes                                 0.008684  1.000000  0.455480  0.035138
# dislikes                              0.006850  0.455480  1.000000 -0.001096
# Year                                  0.012764  0.035138 -0.001096  1.000000
# Month                                -0.006152 -0.008190  0.006096 -0.927310
# Day                                  -0.005483 -0.002433 -0.004119 -0.138459
#
#                            Month       Day
# views                  -0.020483 -0.003961
# comment_count          -0.000557 -0.001488
# ratings_disabled       -0.012004 -0.002311
# video_error_or_removed -0.006152 -0.005483
# likes                  -0.008190 -0.002433
# dislikes                0.006096 -0.004119
# Year                   -0.927310 -0.138459
# Month                   1.000000  0.076012
# Day                     0.076012  1.000000

# %%
# Heatmap for representation of the given correlation 
sns.heatmap(correlation)
plt.show()
print("Conclusion: It can be noticed that comment counts, views, and likes and dislikes show a moderate to high positive correlation.")
# Out:
# Conclusion: It can be noticed that comment counts, views, and likes and dislikes show a moderate to high positive correlation.

# %%
#How many trending video titles contain capitalized word?

def contains_capitalized_word(s):
    for w in s.split():
        if w.isupper():
            return True
    return False

vd["contains_cap"] = vd["title"].apply(contains_capitalized_word)
vd["contains_cap"].value_counts().plot.pie(y='Does the Title Contain a Capital Word', figsize=(5, 5), title='Does the Title Contain a Capital Word?', ylabel=' ', explode=[0,0.1])

print("Conclusion: Approximately 45% of titles contain a capitalized word which seems to confirm the human tendency to click on a video title with a capital word - the capitalization creates an impression of curiosity and excitement.")
# Out:
# Conclusion: Approximately 45% of titles contain a capitalized word which seems to confirm the human tendency to click on a video title with a capital word - the capitalization creates an impression of curiosity and excitement.

# %%
#Bar Graph for No. of trending videos by country
youtube["country"].value_counts().plot(kind="bar", color= "#FF6A6A", title= "Trending Videos by Country")

print("Conclusion: With Japan having the lowest number of trending videos, followed by India. We observe that Germany, Canada, France and the US tie together with the highestnumer of trending videos.")
# Out:
# Conclusion: With Japan having the lowest number of trending videos, followed by India. We observe that Germany, Canada, France and the US tie together with the highestnumer of trending videos.

# %%
# Publishing year for the trending videos count
youtube['Year'].value_counts()
# Out:
# 2018    191881
# 2017     56371
# Name: Year, dtype: int64

# %%
# Graph for Publishing year for the trending videos
youtube["Year"].value_counts().plot(kind="bar", color="#CAFF70", title= "Publishing Year of the Trending Videos", ylabel="No. of Videos")
# Out:
# <AxesSubplot:title={'center':'Publishing Year of the Trending Videos'}, ylabel='No. of Videos'>

# %%
# Histrogram for the Title Length of trending videos
vd["title_length"] = vd["title"].apply(lambda x: len(x))
plt.hist(vd['title_length'],bins=10,align='right', color='#EED2EE', edgecolor='black')
plt.xlabel('Title Length')
plt.ylabel('No. of Videos')
plt.title('Title Length of Trending Videos')
# Out:
# Text(0.5, 1.0, 'Title Length of Trending Videos')

# %%
# Scatter Plot for views and title length within the merged 'youtube' datasset
views_sample=youtube['views'].sample(n=100000, random_state=1)
titlelength_sample=vd['title_length'].sample(n=100000, random_state=1)
sequence=np.arange(100000)
plt.scatter(views_sample,titlelength_sample,c=sequence)
plt.show()
print("Conclusion: It can be noticed that on a majority of the trending videos have an average length of 50-60 characters. Analyzing the title length in conjunction with the views shows that there is no apparent association between the two variables. However, we also notice that videos that have 100,000,000 views and more have title length between 20 and 80 characters approximately")
# Out:
# Conclusion: It can be noticed that on a majority of the trending videos have an average length of 50-60 characters. Analyzing the title length in conjunction with the views shows that there is no apparent association between the two variables. However, we also notice that videos that have 100,000,000 views and more have title length between 20 and 80 characters approximately

# %%
# Scatter Plot for views and likes within the merged datasset
plt.scatter(youtube['views'],youtube['likes'],c=np.arange(248252))
plt.show()
print("Conclusion: We see that views and likes are truly positively correlated: as one increases, the other increases too.")
# Out:
# Conclusion: We see that views and likes are truly positively correlated: as one increases, the other increases too.

# %%
#Line Graph for number of trending videos published on particular day of the week
youtube['Weekday'].value_counts()
publish_day=pd.DataFrame({'No. of Videos':[35151,36298,34908,34721,35314,36691,35169]},index=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
publish_day.plot.line(xlabel='Day of the Week', ylabel='No. of Videos')
print("On observation, Tuesdays and Saturdays were largely the best days chosen by content creators to upload videos while Wednesday adn Thursday were seen as the worst.")
# Out:
# On observation, Tuesdays and Saturdays were largely the best days chosen by content creators to upload videos while Wednesday adn Thursday were seen as the worst.

# %%
#Which channels have the largest number of trending videos?
channels=vd['channel_title'].value_counts(ascending=False).head(20)
print(channels)
channels.plot(kind="barh",color='#00868B',edgecolor='blue', title= 'Highest number of trending videos')

print("Conclusion: Indian Channels - SET India, VikatanTV, and SAB TV - have the highest number of trending videos. Even in general, the top 20 channels are dominated by Indian channels.")
# Out:
# SET India                             256
# VikatanTV                             255
# SAB TV                                249
# The Late Show with Stephen Colbert    228
# Elhiwar Ettounsi                      213
# WWE                                   188
# ESPN                                  184
# MSNBC                                 179
# CNN                                   178
# Анатолий Шарий                        176
# Study IQ education                    170
# Colors TV                             167
# Saregama TVShows                      161
# Tarang TV                             158
# Promiflash                            157
# Ruhrpottwache                         157
# The Young Turks                       156
# RadaanMedia                           155
# etvteluguindia                        153
# THIRU TV                              151
# Name: channel_title, dtype: int64
# Conclusion: Indian Channels - SET India, VikatanTV, and SAB TV - have the highest number of trending videos. Even in general, the top 20 channels are dominated by Indian channels.

# %%
# Finding the most controversial videos
#Controversial videos could be defined here as the ikes and dislikes that have a 10% difference.
# Sorting based on highest number of views
youtube = youtube.sort_values(by=["views"],
     ascending=False)

# %%
#Making a new column with the percentage difference between likes and dislikes
youtube["Controversial score"] = np.abs(youtube["likes"] - youtube["dislikes"])/(youtube["likes"]+youtube["dislikes"])

# %%
youtube1= youtube[(youtube["Controversial score"] < 0.1 ) ]
youtube1
# Out:
#            video_id trending_date       views  comment_count  \
# 139670  QwZT7T-TXT0    2018-01-09  37539570.0      1361580.0
# 218784  QwZT7T-TXT0    2018-01-09  37539570.0      1361580.0
# 218566  QwZT7T-TXT0    2018-01-08  35983135.0      1321281.0
# 139463  QwZT7T-TXT0    2018-01-08  35983135.0      1321281.0
# 139267  QwZT7T-TXT0    2018-01-07  33998325.0      1281099.0
# ...             ...           ...         ...            ...
# 234397  Ud5Lq7D5YvU    2018-03-31         NaN            NaN
# 237525  NWOz3OZ6J9M    2018-04-22         NaN        16813.0
# 237604  HNvX4pY1TLI    2018-04-22         NaN        14172.0
# 238971  YKWGQyz-oLw    2018-04-29         NaN            NaN
# 240720  0IaG9oM4O4s    2018-05-08         NaN            0.0
#
#        comments_disabled  ratings_disabled  video_error_or_removed country  \
# 139670                 0             False                   False  UK
# 218784                 0             False                   False  US
# 218566                 0             False                   False  US
# 139463                 0             False                   False  UK
# 139267                 0             False                   False  UK
# ...                  ...               ...                     ...     ...
# 234397                 0             False                   False  US
# 237525                 0             False                   False  US
# 237604                 0             False                   False  US
# 238971                 0             False                   False  US
# 240720                 1             False                   False  US
#
#           likes  dislikes  Year  Month  Day   Weekday  Controversial score
# 139670  1402579   1674420  2018      1    9   Tuesday             0.088346
# 218784  1402578   1674420  2018      1    9   Tuesday             0.088346
# 218566  1370845   1611043  2018      1    8    Monday             0.080552
# 139463  1370846   1611044  2018      1    8    Monday             0.080552
# 139267  1325297   1517522  2018      1    7    Sunday             0.067618
# ...         ...       ...   ...    ...  ...       ...                  ...
# 234397     9025      8476  2018      3   31  Saturday             0.031370
# 237525     8121      7819  2018      4   22    Sunday             0.018946
# 237604     7867      8763  2018      4   22    Sunday             0.053879
# 238971    14723     12596  2018      4   29    Sunday             0.077858
# 240720     6529      6316  2018      5    8   Tuesday             0.016582
#
# [1853 rows x 15 columns]

# %%
print(youtube["Controversial score"].describe())
print(" ")
print("Conclusion: It is generally assumed that controversial videos tend to get viral and thus, I attempted to construct a controversial score for the trending videos. It can be seen here that this score ranges from 0 to 0.5.")
# Out:
# count    244458.000000
# mean          0.847810
# std           0.178984
# min           0.000000
# 25%           0.809071
# 50%           0.918069
# 75%           0.961420
# max           1.000000
# Name: Controversial score, dtype: float64
#
# Conclusion: It is generally assumed that controversial videos tend to get viral and thus, I attempted to construct a controversial score for the trending videos. It can be seen here that this score ranges from 0 to 0.5.
